# %% [markdown]
# <a href="https://colab.research.google.com/github/fambargh/evaluate/blob/master/segmentation_backbone2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install -U git+https://github.com/albu/albumentations --no-cache-dir
# Out:
# Collecting git+https://github.com/albu/albumentations
#   Cloning https://github.com/albu/albumentations to /tmp/pip-req-build-q744lqfz
#   Running command git clone -q https://github.com/albu/albumentations /tmp/pip-req-build-q744lqfz
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.17.4)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (1.3.3)
# Requirement already satisfied, skipping upgrade: imgaug<0.2.7,>=0.2.5 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (0.2.6)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (3.13)
# Requirement already satisfied, skipping upgrade: opencv-python>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from albumentations==0.4.4) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.11.0 in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.12.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (3.1.2)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.1)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.3.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (4.4.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.6.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (1.1.0)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (0.46)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.11.0->imgaug<0.2.7,>=0.2.5->albumentations==0.4.4) (42.0.2)
# Building wheels for collected packages: albumentations
#   Building wheel for albumentations (setup.py) ... done
#   Created wheel for albumentations: filename=albumentations-0.4.4-cp36-none-any.whl size=61973 sha256=1537e9c7a678a4efa5b9af3977156d88e58f967620822241642660d58aae1901
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r9bskx1o/wheels/45/8b/e4/2837bbcf517d00732b8e394f8646f22b8723ac00993230188b
# Successfully built albumentations
# Installing collected packages: albumentations
#   Found existing installation: albumentations 0.4.4
#     Uninstalling albumentations-0.4.4:
#       Successfully uninstalled albumentations-0.4.4
# Successfully installed albumentations-0.4.4

# %%
# Install required libs

### please update Albumentations to version>=0.3.0 for `Lambda` transform support
#!pip install -U albumentations>=0.3.0 --user 
# !pip install -U --pre segmentation-models --user
# Out:
# Collecting segmentation-models
#   Downloading https://files.pythonhosted.org/packages/70/14/090ea95a4f69c453731d9df3feff0a08e0dea0e8dff932dc4839ec4dab5c/segmentation_models-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from segmentation-models) (1.0.8)
# Collecting efficientnet==1.0.0
#   Downloading https://files.pythonhosted.org/packages/97/82/f3ae07316f0461417dc54affab6e86ab188a5a22f33176d35271628b96e0/efficientnet-1.0.0-py3-none-any.whl
# Collecting image-classifiers==1.0.0
#   Downloading https://files.pythonhosted.org/packages/81/98/6f84720e299a4942ab80df5f76ab97b7828b24d1de5e9b2cbbe6073228b7/image_classifiers-1.0.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.17.4)
# Requirement already satisfied, skipping upgrade: scikit-image in /usr/local/lib/python3.6/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.15.0)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.12.0)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (4.3.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.1.2)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.3)
# Requirement already satisfied, skipping upgrade: imageio>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.1)
# Requirement already satisfied, skipping upgrade: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.3.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.46)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (1.1.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.4.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (2.6.1)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image->efficientnet==1.0.0->segmentation-models) (4.4.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib!=3.0.0,>=2.0.0->scikit-image->efficientnet==1.0.0->segmentation-models) (42.0.2)
# Installing collected packages: efficientnet, image-classifiers, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 segmentation-models-1.0.0

# %%
from zipfile import ZipFile
filename = "total.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
filename = "annotate_cup.zip"

with ZipFile(filename,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
import os
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
x_train_dir = '/content/image_train/'
y_train_dir = '/content/annotation_cup_train/'

x_valid_dir = '/content/image_valid/'
y_valid_dir = '/content/annotation_cup_valid'

x_test_dir = '/content/image_test/'
y_test_dir = '/content/annotation_cup_test/'

# %%
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()
    
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x
    

# classes for data loading and preprocessing
class Dataset:
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    
    CLASSES = ['bg', 'oc','s']
    
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None, 
            augmentation=None, 
            preprocessing=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        
        # convert str names to class values on masks
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing
    
    def __getitem__(self, i):
        
        # read data
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        # extract certain classes from mask (e.g. cars)
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        
        # apply preprocessing
        if self.preprocessing:
            sample = self.preprocessing(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
            
        return image, mask
        
    def __len__(self):
        return len(self.ids)
    
    
class Dataloder(keras.utils.Sequence):
    """Load data from dataset and form batches
    
    Args:
        dataset: instance of Dataset class for image loading and preprocessing.
        batch_size: Integet number of images in batch.
        shuffle: Boolean, if `True` shuffle image indexes each epoch.
    """
    
    def __init__(self, dataset, batch_size=1, shuffle=False):
        self.dataset = dataset
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(dataset))

        self.on_epoch_end()

    def __getitem__(self, i):
        
        # collect batch data
        start = i * self.batch_size
        stop = (i + 1) * self.batch_size
        data = []
        for j in range(start, stop):
            data.append(self.dataset[j])
        
        # transpose list of lists
        batch = [np.stack(samples, axis=0) for samples in zip(*data)]
        
        return batch
    
    def __len__(self):
        """Denotes the number of batches per epoch"""
        return len(self.indexes) // self.batch_size
    
    def on_epoch_end(self):
        """Callback function to shuffle indexes each epoch"""
        if self.shuffle:
            self.indexes = np.random.permutation(self.indexes)

# %%
# Lets look at data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['oc','bg'])

image, mask = dataset[5] # get some sample
visualize(
    image=image, 
    OC_mask=mask[..., 0].squeeze(),
    sky_mask=mask[..., 1].squeeze(),
    background_mask=mask[..., 2].squeeze(),
)

# %%
import albumentations as A

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

# define heavy augmentations
def get_training_augmentation():
    train_transform = [

        A.HorizontalFlip(p=0.5),

        A.ShiftScaleRotate(scale_limit=0.5, rotate_limit=0, shift_limit=0.1, p=1, border_mode=0),

        A.PadIfNeeded(min_height=128, min_width=128, always_apply=True, border_mode=0),
        A.RandomCrop(height=128, width=128, always_apply=True),

        A.IAAAdditiveGaussianNoise(p=0.2),
        A.IAAPerspective(p=0.5),

        A.OneOf(
            [
                A.CLAHE(p=1),
                A.RandomBrightness(p=1),
                A.RandomGamma(p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.IAASharpen(p=1),
                A.Blur(blur_limit=3, p=1),
                A.MotionBlur(blur_limit=3, p=1),
            ],
            p=0.9,
        ),

        A.OneOf(
            [
                A.RandomContrast(p=1),
                A.HueSaturationValue(p=1),
            ],
            p=0.9,
        ),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.PadIfNeeded(128, 128)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    
    _transform = [
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
# Lets look at augmented data we have
dataset = Dataset(x_train_dir, y_train_dir, classes=['oc', 'bg'], augmentation=get_training_augmentation())

image, mask = dataset[12] # get some sample
visualize(
    image=image, 
    OC_mask=mask[..., 0].squeeze(),
    sky_mask=mask[..., 1].squeeze(),
    background_mask=mask[..., 2].squeeze(),
)
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "

# %%
import segmentation_models as sm

# segmentation_models could also use `tf.keras` if you do not have Keras installed
# or you could switch to other framework using `sm.set_framework('tf.keras')`
# Out:
# Segmentation Models: using `keras` framework.

# %%
#BACKBONE = 'seresnet50'
BATCH_SIZE = 2
CLASSES = ['oc']
#LR = 0.01
EPOCHS = 30

preprocess_input = sm.get_preprocessing(BACKBONE)

# %%
n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
activation = 'sigmoid' if n_classes == 1 else 'softmax'

# %%
# Dataset for train images
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES, 
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

# Dataset for validation images
valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)

# check shapes for errors
assert train_dataloader[0][0].shape == (BATCH_SIZE, 128, 128, 3)
assert train_dataloader[0][1].shape == (BATCH_SIZE, 128, 128, n_classes)

# define callbacks for learning rate scheduling and best checkpoints saving
callbacks = [
    keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
    keras.callbacks.ReduceLROnPlateau(),
]
# Out:
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c990ebcb0e4f> in <module>()
#       4     classes=CLASSES,
#       5     augmentation=get_training_augmentation(),
# ----> 6     preprocessing=get_preprocessing(preprocess_input),
#       7 )
#       8
#
# NameError: name 'preprocess_input' is not defined

# %%
# study of learning rate on accuracy for blobs problem
from sklearn.datasets.samples_generator import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD, RMSprop, Adagrad,Adadelta, Adam, Adamax, Nadam
from keras.utils import to_categorical
from matplotlib import pyplot



# fit a model and plot learning curve
def fit_model( BACKBONE):
  BATCH_SIZE = 2
  CLASSES = ['oc']
  #LR = 0.01
  EPOCHS = 30
  n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
  
  preprocess_input = sm.get_preprocessing(BACKBONE)
  # Dataset for train images
  train_dataset = Dataset(
      x_train_dir, 
      y_train_dir, 
      classes=CLASSES, 
      augmentation=get_training_augmentation(),
      preprocessing=get_preprocessing(preprocess_input),
      )
  print(',,,')
  
  # Dataset for validation images
  valid_dataset = Dataset(
      x_valid_dir, 
      y_valid_dir, 
      classes=CLASSES, 
      augmentation=get_validation_augmentation(),
      preprocessing=get_preprocessing(preprocess_input),
      )
  train_dataloader = Dataloder(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
  valid_dataloader = Dataloder(valid_dataset, batch_size=1, shuffle=False)
  # check shapes for errors
  assert train_dataloader[0][0].shape == (BATCH_SIZE, 128, 128, 3)
  assert train_dataloader[0][1].shape == (BATCH_SIZE, 128, 128, n_classes)
  # define callbacks for learning rate scheduling and best checkpoints saving
  callbacks = [
               keras.callbacks.ModelCheckpoint('./best_model.h5', save_weights_only=True, save_best_only=True, mode='min'),
               keras.callbacks.ReduceLROnPlateau(),
               ]
  # define model
  # define network parameters
  n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
  activation = 'sigmoid' if n_classes == 1 else 'softmax'
  model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
  opt = SGD(lr=0.01)
  dice_loss = sm.losses.DiceLoss()
  focal_loss = sm.losses.BinaryFocalLoss() 
  total_loss = dice_loss + (1 * focal_loss)
  metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]
  model.compile(opt, total_loss, metrics)
  ##model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
  # fit model
  history = model.fit_generator(train_dataloader, 
                                steps_per_epoch=len(train_dataloader), 
                                epochs=EPOCHS, 
                                #callbacks=callbacks, 
                                validation_data=valid_dataloader, 
                                validation_steps=len(valid_dataloader),
                                )
  ###history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=0)
  # plot learning curves
  ###plt.plot(history.history[])
  pyplot.plot(history.history['f1-score'], label='train')
  pyplot.plot(history.history['val_f1-score'], label='test')
  pyplot.title('backbone ='+str(backbone), pad=-50)
  #plt.title('Model loss')


# prepare dataset
###trainX, trainy, testX, testy = prepare_data()
# create learning curves for different learning rates
#learning_rates = [ 1E-1, 1E-2, 1E-3, 1E-4, 1E-5, 1E-6]
backbone = ['resnet50', 'resnet18', 'resnet34', 'senet154','efficientnetb2']
#optimum = [SGD(lr=0.01, momentum=0.0, nesterov=False), Adam(lr=0.001, beta_1=0.9, beta_2=0.999), RMSprop(lr=0.001, rho=0.9)]
for i in range(len(backbone)):
	# determine the plot number
  plt.figure(figsize=(30, 25))
  plot_no = 420+(i+1)
  pyplot.subplot(plot_no)
  #plot_no2=820+(i+len(optimum))
  # fit model and plot learning curves for a learning rate
  print('opt is : ' +str(backbone[i]))
  fit_model( backbone[i])
# show learning curves
pyplot.show()
# define network parameters
####activation = 'sigmoid' if n_classes == 1 else 'softmax'

#create model
###model = sm.Unet(BACKBONE, classes=n_classes, activation=activation)
# Out:
# opt is : resnet50
# ,,,
# /usr/local/lib/python3.6/dist-packages/albumentations/augmentations/transforms.py:2910: UserWarning: Using lambda is incompatible with multiprocessing. Consider using regular functions or partial().
#   "Using lambda is incompatible with multiprocessing. "
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/30
# 91/91 [==============================] - 24s 263ms/step - loss: 1.2920 - iou_score: 0.1948 - f1-score: 0.2941 - val_loss: 1.1131 - val_iou_score: 0.2304 - val_f1-score: 0.3181
# Epoch 2/30
# 91/91 [==============================] - 10s 113ms/step - loss: 1.0673 - iou_score: 0.2902 - f1-score: 0.4197 - val_loss: 0.9513 - val_iou_score: 0.2299 - val_f1-score: 0.3063
# Epoch 3/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.9717 - iou_score: 0.3198 - f1-score: 0.4527 - val_loss: 0.9214 - val_iou_score: 0.2399 - val_f1-score: 0.3354
# Epoch 4/30
# 91/91 [==============================] - 10s 113ms/step - loss: 0.9507 - iou_score: 0.3322 - f1-score: 0.4652 - val_loss: 0.9240 - val_iou_score: 0.2549 - val_f1-score: 0.3441
# Epoch 5/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.8771 - iou_score: 0.3732 - f1-score: 0.5110 - val_loss: 0.9997 - val_iou_score: 0.2998 - val_f1-score: 0.3997
# Epoch 6/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.9179 - iou_score: 0.3652 - f1-score: 0.5033 - val_loss: 0.7592 - val_iou_score: 0.4031 - val_f1-score: 0.5208
# Epoch 7/30
# 91/91 [==============================] - 10s 110ms/step - loss: 0.8534 - iou_score: 0.4021 - f1-score: 0.5419 - val_loss: 0.8939 - val_iou_score: 0.2176 - val_f1-score: 0.2936
# Epoch 8/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.7678 - iou_score: 0.4339 - f1-score: 0.5757 - val_loss: 0.6810 - val_iou_score: 0.4097 - val_f1-score: 0.5061
# Epoch 9/30
# 91/91 [==============================] - 10s 113ms/step - loss: 0.7695 - iou_score: 0.4043 - f1-score: 0.5498 - val_loss: 0.8473 - val_iou_score: 0.2353 - val_f1-score: 0.3008
# Epoch 10/30
# 91/91 [==============================] - 10s 110ms/step - loss: 0.6730 - iou_score: 0.4777 - f1-score: 0.6242 - val_loss: 0.8789 - val_iou_score: 0.2834 - val_f1-score: 0.3787
# Epoch 11/30
# 91/91 [==============================] - 10s 114ms/step - loss: 0.7499 - iou_score: 0.4457 - f1-score: 0.5932 - val_loss: 0.8308 - val_iou_score: 0.2359 - val_f1-score: 0.3114
# Epoch 12/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.6908 - iou_score: 0.4946 - f1-score: 0.6373 - val_loss: 0.7761 - val_iou_score: 0.3133 - val_f1-score: 0.3900
# Epoch 13/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.6534 - iou_score: 0.4817 - f1-score: 0.6225 - val_loss: 0.9062 - val_iou_score: 0.2882 - val_f1-score: 0.3742
# Epoch 14/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.5892 - iou_score: 0.5154 - f1-score: 0.6567 - val_loss: 0.7497 - val_iou_score: 0.3395 - val_f1-score: 0.4319
# Epoch 15/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.6043 - iou_score: 0.5094 - f1-score: 0.6511 - val_loss: 0.6544 - val_iou_score: 0.4452 - val_f1-score: 0.5459
# Epoch 16/30
# 91/91 [==============================] - 10s 109ms/step - loss: 0.5497 - iou_score: 0.5520 - f1-score: 0.6896 - val_loss: 0.5584 - val_iou_score: 0.5133 - val_f1-score: 0.6285
# Epoch 17/30
# 91/91 [==============================] - 10s 113ms/step - loss: 0.5863 - iou_score: 0.5298 - f1-score: 0.6716 - val_loss: 0.6662 - val_iou_score: 0.3706 - val_f1-score: 0.4476
# Epoch 18/30
# 91/91 [==============================] - 10s 110ms/step - loss: 0.5336 - iou_score: 0.5557 - f1-score: 0.6944 - val_loss: 0.6964 - val_iou_score: 0.3971 - val_f1-score: 0.4946
# Epoch 19/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.5425 - iou_score: 0.5495 - f1-score: 0.6922 - val_loss: 0.7680 - val_iou_score: 0.2847 - val_f1-score: 0.3541
# Epoch 20/30
# 91/91 [==============================] - 10s 114ms/step - loss: 0.5184 - iou_score: 0.5608 - f1-score: 0.7004 - val_loss: 0.7020 - val_iou_score: 0.3470 - val_f1-score: 0.4383
# Epoch 21/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.5238 - iou_score: 0.5469 - f1-score: 0.6867 - val_loss: 0.6111 - val_iou_score: 0.5084 - val_f1-score: 0.6087
# Epoch 22/30
# 91/91 [==============================] - 10s 114ms/step - loss: 0.5080 - iou_score: 0.5795 - f1-score: 0.7170 - val_loss: 0.6278 - val_iou_score: 0.4480 - val_f1-score: 0.5686
# Epoch 23/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.4833 - iou_score: 0.5814 - f1-score: 0.7190 - val_loss: 0.5930 - val_iou_score: 0.4750 - val_f1-score: 0.5913
# Epoch 24/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.4888 - iou_score: 0.5647 - f1-score: 0.6997 - val_loss: 0.5841 - val_iou_score: 0.4943 - val_f1-score: 0.6115
# Epoch 25/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.4549 - iou_score: 0.5944 - f1-score: 0.7288 - val_loss: 0.5095 - val_iou_score: 0.5365 - val_f1-score: 0.6546
# Epoch 26/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.4397 - iou_score: 0.6008 - f1-score: 0.7319 - val_loss: 0.6401 - val_iou_score: 0.4962 - val_f1-score: 0.6212
# Epoch 27/30
# 91/91 [==============================] - 10s 111ms/step - loss: 0.4603 - iou_score: 0.6030 - f1-score: 0.7353 - val_loss: 0.5282 - val_iou_score: 0.5848 - val_f1-score: 0.7077
# Epoch 28/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.4019 - iou_score: 0.6225 - f1-score: 0.7544 - val_loss: 0.6550 - val_iou_score: 0.4514 - val_f1-score: 0.5835
# Epoch 29/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.4027 - iou_score: 0.6095 - f1-score: 0.7402 - val_loss: 0.4368 - val_iou_score: 0.6322 - val_f1-score: 0.7390
# Epoch 30/30
# 91/91 [==============================] - 10s 112ms/step - loss: 0.4511 - iou_score: 0.5928 - f1-score: 0.7272 - val_loss: 0.4641 - val_iou_score: 0.6077 - val_f1-score: 0.7372
# opt is : resnet18
# ,,,
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 2s 0us/step
# Epoch 1/30
# 91/91 [==============================] - 13s 141ms/step - loss: 1.2891 - iou_score: 0.1891 - f1-score: 0.2893 - val_loss: 1.3439 - val_iou_score: 0.2122 - val_f1-score: 0.3144
# Epoch 2/30
# 91/91 [==============================] - 5s 59ms/step - loss: 1.0221 - iou_score: 0.3006 - f1-score: 0.4270 - val_loss: 1.2384 - val_iou_score: 0.2843 - val_f1-score: 0.3912
# Epoch 3/30
# 91/91 [==============================] - 5s 59ms/step - loss: 0.9342 - iou_score: 0.3499 - f1-score: 0.4874 - val_loss: 1.5581 - val_iou_score: 0.2242 - val_f1-score: 0.3363
# Epoch 4/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.9061 - iou_score: 0.3625 - f1-score: 0.4990 - val_loss: 0.9730 - val_iou_score: 0.2520 - val_f1-score: 0.3445
# Epoch 5/30
# 91/91 [==============================] - 5s 60ms/step - loss: 0.8479 - iou_score: 0.3858 - f1-score: 0.5263 - val_loss: 0.9400 - val_iou_score: 0.3295 - val_f1-score: 0.4406
# Epoch 6/30
# 91/91 [==============================] - 5s 60ms/step - loss: 0.8270 - iou_score: 0.4161 - f1-score: 0.5632 - val_loss: 0.9277 - val_iou_score: 0.2740 - val_f1-score: 0.3580
# Epoch 7/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.6901 - iou_score: 0.4545 - f1-score: 0.6015 - val_loss: 1.0680 - val_iou_score: 0.1783 - val_f1-score: 0.2494
# Epoch 8/30
# 91/91 [==============================] - 5s 60ms/step - loss: 0.6946 - iou_score: 0.4650 - f1-score: 0.6063 - val_loss: 1.1643 - val_iou_score: 0.1452 - val_f1-score: 0.1793
# Epoch 9/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.6778 - iou_score: 0.4959 - f1-score: 0.6397 - val_loss: 0.9902 - val_iou_score: 0.2022 - val_f1-score: 0.2496
# Epoch 10/30
# 91/91 [==============================] - 5s 58ms/step - loss: 0.6574 - iou_score: 0.5120 - f1-score: 0.6554 - val_loss: 0.8521 - val_iou_score: 0.2710 - val_f1-score: 0.3332
# Epoch 11/30
# 91/91 [==============================] - 5s 60ms/step - loss: 0.6535 - iou_score: 0.4895 - f1-score: 0.6328 - val_loss: 0.9125 - val_iou_score: 0.2465 - val_f1-score: 0.3312
# Epoch 12/30
# 91/91 [==============================] - 5s 60ms/step - loss: 0.5807 - iou_score: 0.5411 - f1-score: 0.6817 - val_loss: 0.6388 - val_iou_score: 0.5210 - val_f1-score: 0.6444
# Epoch 13/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5929 - iou_score: 0.5330 - f1-score: 0.6743 - val_loss: 0.7690 - val_iou_score: 0.3287 - val_f1-score: 0.3960
# Epoch 14/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5968 - iou_score: 0.5312 - f1-score: 0.6733 - val_loss: 0.6743 - val_iou_score: 0.4844 - val_f1-score: 0.6081
# Epoch 15/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5926 - iou_score: 0.5399 - f1-score: 0.6798 - val_loss: 0.6129 - val_iou_score: 0.5262 - val_f1-score: 0.6493
# Epoch 16/30
# 91/91 [==============================] - 5s 58ms/step - loss: 0.4908 - iou_score: 0.5750 - f1-score: 0.7124 - val_loss: 0.6340 - val_iou_score: 0.4295 - val_f1-score: 0.5270
# Epoch 17/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.5002 - iou_score: 0.5783 - f1-score: 0.7129 - val_loss: 0.5580 - val_iou_score: 0.5530 - val_f1-score: 0.6740
# Epoch 18/30
# 91/91 [==============================] - 5s 59ms/step - loss: 0.5207 - iou_score: 0.5643 - f1-score: 0.6985 - val_loss: 0.7092 - val_iou_score: 0.3939 - val_f1-score: 0.4830
# Epoch 19/30
# 91/91 [==============================] - 5s 58ms/step - loss: 0.4667 - iou_score: 0.5888 - f1-score: 0.7231 - val_loss: 0.5302 - val_iou_score: 0.5796 - val_f1-score: 0.7024
# Epoch 20/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.4646 - iou_score: 0.5829 - f1-score: 0.7197 - val_loss: 0.5998 - val_iou_score: 0.5494 - val_f1-score: 0.6869
# Epoch 21/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.4799 - iou_score: 0.5995 - f1-score: 0.7311 - val_loss: 0.6821 - val_iou_score: 0.4161 - val_f1-score: 0.5219
# Epoch 22/30
# 91/91 [==============================] - 5s 58ms/step - loss: 0.4446 - iou_score: 0.6018 - f1-score: 0.7375 - val_loss: 0.6678 - val_iou_score: 0.4157 - val_f1-score: 0.5179
# Epoch 23/30
# 91/91 [==============================] - 5s 59ms/step - loss: 0.4484 - iou_score: 0.6101 - f1-score: 0.7406 - val_loss: 0.5662 - val_iou_score: 0.5309 - val_f1-score: 0.6596
# Epoch 24/30
# 91/91 [==============================] - 5s 58ms/step - loss: 0.4738 - iou_score: 0.6048 - f1-score: 0.7351 - val_loss: 0.5685 - val_iou_score: 0.5816 - val_f1-score: 0.7096
# Epoch 25/30
# 91/91 [==============================] - 6s 61ms/step - loss: 0.4315 - iou_score: 0.6226 - f1-score: 0.7525 - val_loss: 0.5666 - val_iou_score: 0.5308 - val_f1-score: 0.6560
# Epoch 26/30
# 91/91 [==============================] - 5s 58ms/step - loss: 0.4074 - iou_score: 0.6361 - f1-score: 0.7638 - val_loss: 0.5187 - val_iou_score: 0.5732 - val_f1-score: 0.6969
# Epoch 27/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.3932 - iou_score: 0.6365 - f1-score: 0.7657 - val_loss: 0.5009 - val_iou_score: 0.5877 - val_f1-score: 0.7117
# Epoch 28/30
# 91/91 [==============================] - 5s 57ms/step - loss: 0.3947 - iou_score: 0.6376 - f1-score: 0.7642 - val_loss: 0.5135 - val_iou_score: 0.5403 - val_f1-score: 0.6566
# Epoch 29/30
# 91/91 [==============================] - 5s 59ms/step - loss: 0.3588 - iou_score: 0.6773 - f1-score: 0.7975 - val_loss: 0.5713 - val_iou_score: 0.4588 - val_f1-score: 0.5527
# Epoch 30/30
# 91/91 [==============================] - 5s 59ms/step - loss: 0.3983 - iou_score: 0.6289 - f1-score: 0.7564 - val_loss: 0.5034 - val_iou_score: 0.5438 - val_f1-score: 0.6634
# opt is : resnet34
# ,,,
# Epoch 1/30
# 91/91 [==============================] - 19s 204ms/step - loss: 1.2421 - iou_score: 0.1185 - f1-score: 0.1826 - val_loss: 1.3970 - val_iou_score: 0.2085 - val_f1-score: 0.3096
# Epoch 2/30
# 91/91 [==============================] - 8s 86ms/step - loss: 1.0316 - iou_score: 0.3017 - f1-score: 0.4224 - val_loss: 1.2707 - val_iou_score: 0.1055 - val_f1-score: 0.1605
# Epoch 3/30
# 91/91 [==============================] - 8s 87ms/step - loss: 0.9524 - iou_score: 0.3309 - f1-score: 0.4645 - val_loss: 0.9783 - val_iou_score: 0.2544 - val_f1-score: 0.3506
# Epoch 4/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8831 - iou_score: 0.3577 - f1-score: 0.4908 - val_loss: 0.8660 - val_iou_score: 0.3521 - val_f1-score: 0.4634
# Epoch 5/30
# 91/91 [==============================] - 8s 84ms/step - loss: 0.8675 - iou_score: 0.3847 - f1-score: 0.5182 - val_loss: 0.9776 - val_iou_score: 0.2481 - val_f1-score: 0.3284
# Epoch 6/30
# 91/91 [==============================] - 8s 86ms/step - loss: 0.8600 - iou_score: 0.3833 - f1-score: 0.5244 - val_loss: 0.9975 - val_iou_score: 0.1776 - val_f1-score: 0.2484
# Epoch 7/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.8231 - iou_score: 0.4201 - f1-score: 0.5591 - val_loss: 0.8284 - val_iou_score: 0.3401 - val_f1-score: 0.4253
# Epoch 8/30
# 91/91 [==============================] - 8s 86ms/step - loss: 0.7883 - iou_score: 0.4300 - f1-score: 0.5712 - val_loss: 0.8298 - val_iou_score: 0.2958 - val_f1-score: 0.4000
# Epoch 9/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.7134 - iou_score: 0.4747 - f1-score: 0.6156 - val_loss: 0.8227 - val_iou_score: 0.3360 - val_f1-score: 0.4334
# Epoch 10/30
# 91/91 [==============================] - 8s 84ms/step - loss: 0.6764 - iou_score: 0.4834 - f1-score: 0.6257 - val_loss: 0.6933 - val_iou_score: 0.4159 - val_f1-score: 0.5212
# Epoch 11/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.6787 - iou_score: 0.4982 - f1-score: 0.6431 - val_loss: 0.6651 - val_iou_score: 0.4356 - val_f1-score: 0.5390
# Epoch 12/30
# 91/91 [==============================] - 8s 84ms/step - loss: 0.5841 - iou_score: 0.5219 - f1-score: 0.6658 - val_loss: 0.7406 - val_iou_score: 0.3504 - val_f1-score: 0.4557
# Epoch 13/30
# 91/91 [==============================] - 8s 87ms/step - loss: 0.5488 - iou_score: 0.5550 - f1-score: 0.6932 - val_loss: 0.5434 - val_iou_score: 0.4952 - val_f1-score: 0.6106
# Epoch 14/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5041 - iou_score: 0.5722 - f1-score: 0.7053 - val_loss: 0.7950 - val_iou_score: 0.3262 - val_f1-score: 0.4358
# Epoch 15/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5434 - iou_score: 0.5533 - f1-score: 0.6944 - val_loss: 0.9106 - val_iou_score: 0.3003 - val_f1-score: 0.3979
# Epoch 16/30
# 91/91 [==============================] - 8s 86ms/step - loss: 0.5677 - iou_score: 0.5403 - f1-score: 0.6801 - val_loss: 0.5859 - val_iou_score: 0.5176 - val_f1-score: 0.6370
# Epoch 17/30
# 91/91 [==============================] - 8s 84ms/step - loss: 0.5516 - iou_score: 0.5554 - f1-score: 0.6901 - val_loss: 0.6136 - val_iou_score: 0.4717 - val_f1-score: 0.5796
# Epoch 18/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5470 - iou_score: 0.5598 - f1-score: 0.6986 - val_loss: 0.5933 - val_iou_score: 0.4895 - val_f1-score: 0.5977
# Epoch 19/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4790 - iou_score: 0.5860 - f1-score: 0.7227 - val_loss: 0.5790 - val_iou_score: 0.4752 - val_f1-score: 0.5831
# Epoch 20/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.5108 - iou_score: 0.5723 - f1-score: 0.7086 - val_loss: 0.6618 - val_iou_score: 0.4560 - val_f1-score: 0.5732
# Epoch 21/30
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4632 - iou_score: 0.6059 - f1-score: 0.7374 - val_loss: 0.6281 - val_iou_score: 0.5024 - val_f1-score: 0.6292
# Epoch 22/30
# 91/91 [==============================] - 8s 84ms/step - loss: 0.4718 - iou_score: 0.6032 - f1-score: 0.7341 - val_loss: 0.6834 - val_iou_score: 0.5435 - val_f1-score: 0.6619
# Epoch 23/30
# 91/91 [==============================] - 8s 88ms/step - loss: 0.4330 - iou_score: 0.6127 - f1-score: 0.7408 - val_loss: 0.5263 - val_iou_score: 0.5325 - val_f1-score: 0.6495
# Epoch 24/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4574 - iou_score: 0.6238 - f1-score: 0.7527 - val_loss: 0.6261 - val_iou_score: 0.3963 - val_f1-score: 0.4824
# Epoch 25/30
# 91/91 [==============================] - 8s 88ms/step - loss: 0.4319 - iou_score: 0.6070 - f1-score: 0.7383 - val_loss: 0.5475 - val_iou_score: 0.5200 - val_f1-score: 0.6256
# Epoch 26/30
# 91/91 [==============================] - 8s 85ms/step - loss: 0.4539 - iou_score: 0.5974 - f1-score: 0.7326 - val_loss: 0.5574 - val_iou_score: 0.4624 - val_f1-score: 0.5753
# Epoch 27/30
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4064 - iou_score: 0.6359 - f1-score: 0.7625 - val_loss: 0.4133 - val_iou_score: 0.6260 - val_f1-score: 0.7362
# Epoch 28/30
# 91/91 [==============================] - 8s 87ms/step - loss: 0.4313 - iou_score: 0.6231 - f1-score: 0.7537 - val_loss: 0.4679 - val_iou_score: 0.5698 - val_f1-score: 0.6874
# Epoch 29/30
# 91/91 [==============================] - 8s 86ms/step - loss: 0.4078 - iou_score: 0.6286 - f1-score: 0.7542 - val_loss: 0.5132 - val_iou_score: 0.5299 - val_f1-score: 0.6409
# Epoch 30/30
# 91/91 [==============================] - 8s 87ms/step - loss: 0.3831 - iou_score: 0.6395 - f1-score: 0.7676 - val_loss: 0.6150 - val_iou_score: 0.4380 - val_f1-score: 0.5536
# opt is : senet154
# ,,,
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/senet154_imagenet_1000_no_top.h5
# 466640896/466635528 [==============================] - 14s 0us/step
# Epoch 1/30
# 91/91 [==============================] - 864s 9s/step - loss: 1.2676 - iou_score: 0.2153 - f1-score: 0.3317 - val_loss: 1.4738 - val_iou_score: 0.2595 - val_f1-score: 0.3722
# Epoch 2/30
# 91/91 [==============================] - 91s 1s/step - loss: 1.0070 - iou_score: 0.3215 - f1-score: 0.4554 - val_loss: 1.2177 - val_iou_score: 0.3082 - val_f1-score: 0.4220
# Epoch 3/30
# 91/91 [==============================] - 92s 1s/step - loss: 0.8113 - iou_score: 0.4016 - f1-score: 0.5401 - val_loss: 2.9221 - val_iou_score: 0.2140 - val_f1-score: 0.2999
# Epoch 4/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.7989 - iou_score: 0.4397 - f1-score: 0.5809 - val_loss: 0.6544 - val_iou_score: 0.4471 - val_f1-score: 0.5704
# Epoch 5/30
# 91/91 [==============================] - 92s 1s/step - loss: 0.7053 - iou_score: 0.4801 - f1-score: 0.6187 - val_loss: 0.5653 - val_iou_score: 0.5048 - val_f1-score: 0.6299
# Epoch 6/30
# 91/91 [==============================] - 90s 994ms/step - loss: 0.6897 - iou_score: 0.4993 - f1-score: 0.6415 - val_loss: 0.8424 - val_iou_score: 0.4508 - val_f1-score: 0.5923
# Epoch 7/30
# 91/91 [==============================] - 91s 997ms/step - loss: 0.6334 - iou_score: 0.5110 - f1-score: 0.6529 - val_loss: 0.5614 - val_iou_score: 0.5436 - val_f1-score: 0.6715
# Epoch 8/30
# 91/91 [==============================] - 92s 1s/step - loss: 0.5927 - iou_score: 0.5496 - f1-score: 0.6895 - val_loss: 0.5103 - val_iou_score: 0.5691 - val_f1-score: 0.6968
# Epoch 9/30
# 91/91 [==============================] - 91s 998ms/step - loss: 0.6000 - iou_score: 0.5561 - f1-score: 0.6929 - val_loss: 0.6155 - val_iou_score: 0.4849 - val_f1-score: 0.5985
# Epoch 10/30
# 91/91 [==============================] - 91s 995ms/step - loss: 0.5805 - iou_score: 0.5558 - f1-score: 0.6971 - val_loss: 0.4747 - val_iou_score: 0.5840 - val_f1-score: 0.7060
# Epoch 11/30
# 91/91 [==============================] - 91s 995ms/step - loss: 0.5111 - iou_score: 0.5824 - f1-score: 0.7174 - val_loss: 0.8965 - val_iou_score: 0.2827 - val_f1-score: 0.3822
# Epoch 12/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.5118 - iou_score: 0.5980 - f1-score: 0.7326 - val_loss: 0.4195 - val_iou_score: 0.6131 - val_f1-score: 0.7286
# Epoch 13/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.5008 - iou_score: 0.6074 - f1-score: 0.7415 - val_loss: 0.4157 - val_iou_score: 0.6180 - val_f1-score: 0.7452
# Epoch 14/30
# 91/91 [==============================] - 93s 1s/step - loss: 0.4815 - iou_score: 0.6140 - f1-score: 0.7463 - val_loss: 0.3811 - val_iou_score: 0.6507 - val_f1-score: 0.7624
# Epoch 15/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.4591 - iou_score: 0.6258 - f1-score: 0.7512 - val_loss: 0.3637 - val_iou_score: 0.6653 - val_f1-score: 0.7708
# Epoch 16/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.4744 - iou_score: 0.6256 - f1-score: 0.7542 - val_loss: 0.4129 - val_iou_score: 0.6348 - val_f1-score: 0.7461
# Epoch 17/30
# 91/91 [==============================] - 92s 1s/step - loss: 0.4196 - iou_score: 0.6553 - f1-score: 0.7817 - val_loss: 0.3887 - val_iou_score: 0.6503 - val_f1-score: 0.7553
# Epoch 18/30
# 91/91 [==============================] - 91s 1000ms/step - loss: 0.3957 - iou_score: 0.6773 - f1-score: 0.7958 - val_loss: 0.4439 - val_iou_score: 0.6233 - val_f1-score: 0.7474
# Epoch 19/30
# 91/91 [==============================] - 92s 1s/step - loss: 0.4132 - iou_score: 0.6525 - f1-score: 0.7773 - val_loss: 0.3190 - val_iou_score: 0.6937 - val_f1-score: 0.7978
# Epoch 20/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.3638 - iou_score: 0.6799 - f1-score: 0.7967 - val_loss: 0.4967 - val_iou_score: 0.5501 - val_f1-score: 0.6622
# Epoch 21/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.3646 - iou_score: 0.6805 - f1-score: 0.8017 - val_loss: 0.3467 - val_iou_score: 0.6625 - val_f1-score: 0.7750
# Epoch 22/30
# 91/91 [==============================] - 90s 994ms/step - loss: 0.3526 - iou_score: 0.6827 - f1-score: 0.8001 - val_loss: 0.4082 - val_iou_score: 0.6502 - val_f1-score: 0.7736
# Epoch 23/30
# 91/91 [==============================] - 90s 993ms/step - loss: 0.3037 - iou_score: 0.7028 - f1-score: 0.8144 - val_loss: 0.3565 - val_iou_score: 0.6707 - val_f1-score: 0.7808
# Epoch 24/30
# 91/91 [==============================] - 91s 1s/step - loss: 0.3609 - iou_score: 0.6817 - f1-score: 0.7988 - val_loss: 0.3480 - val_iou_score: 0.6857 - val_f1-score: 0.7976
# Epoch 25/30
# 91/91 [==============================] - 91s 997ms/step - loss: 0.3389 - iou_score: 0.6968 - f1-score: 0.8116 - val_loss: 0.3709 - val_iou_score: 0.6613 - val_f1-score: 0.7786
# Epoch 26/30
# 91/91 [==============================] - 92s 1s/step - loss: 0.3064 - iou_score: 0.7102 - f1-score: 0.8214 - val_loss: 0.4406 - val_iou_score: 0.6602 - val_f1-score: 0.7804
# Epoch 27/30
# 91/91 [==============================] - 93s 1s/step - loss: 0.3305 - iou_score: 0.6963 - f1-score: 0.8116 - val_loss: 0.3304 - val_iou_score: 0.6813 - val_f1-score: 0.7931
# Epoch 28/30
# 91/91 [==============================] - 93s 1s/step - loss: 0.3155 - iou_score: 0.7037 - f1-score: 0.8185 - val_loss: 0.3435 - val_iou_score: 0.7036 - val_f1-score: 0.8133
# Epoch 29/30
# 91/91 [==============================] - 93s 1s/step - loss: 0.3179 - iou_score: 0.7145 - f1-score: 0.8266 - val_loss: 0.3822 - val_iou_score: 0.6286 - val_f1-score: 0.7332
# Epoch 30/30
# 91/91 [==============================] - 94s 1s/step - loss: 0.3089 - iou_score: 0.7165 - f1-score: 0.8262 - val_loss: 0.3480 - val_iou_score: 0.6501 - val_f1-score: 0.7496
# opt is : efficientnetb2
# ,,,
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b2_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 31940608/31936256 [==============================] - 2s 0us/step
# Epoch 1/30
# 91/91 [==============================] - 56s 618ms/step - loss: 1.2885 - iou_score: 0.1950 - f1-score: 0.3026 - val_loss: 1.1153 - val_iou_score: 0.3102 - val_f1-score: 0.4252
# Epoch 2/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.9552 - iou_score: 0.3428 - f1-score: 0.4775 - val_loss: 0.7880 - val_iou_score: 0.3764 - val_f1-score: 0.4840
# Epoch 3/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.8815 - iou_score: 0.3765 - f1-score: 0.5131 - val_loss: 0.7126 - val_iou_score: 0.4508 - val_f1-score: 0.5562
# Epoch 4/30
# 91/91 [==============================] - 12s 136ms/step - loss: 0.7644 - iou_score: 0.4212 - f1-score: 0.5624 - val_loss: 0.6619 - val_iou_score: 0.4478 - val_f1-score: 0.5576
# Epoch 5/30
# 91/91 [==============================] - 12s 133ms/step - loss: 0.8528 - iou_score: 0.4121 - f1-score: 0.5524 - val_loss: 0.7408 - val_iou_score: 0.3932 - val_f1-score: 0.5090
# Epoch 6/30
# 91/91 [==============================] - 12s 133ms/step - loss: 0.7758 - iou_score: 0.4417 - f1-score: 0.5804 - val_loss: 0.8029 - val_iou_score: 0.3669 - val_f1-score: 0.4703
# Epoch 7/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.7832 - iou_score: 0.4615 - f1-score: 0.6017 - val_loss: 0.5257 - val_iou_score: 0.5388 - val_f1-score: 0.6463
# Epoch 8/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.6645 - iou_score: 0.5050 - f1-score: 0.6471 - val_loss: 0.5370 - val_iou_score: 0.5424 - val_f1-score: 0.6478
# Epoch 9/30
# 91/91 [==============================] - 12s 134ms/step - loss: 0.6997 - iou_score: 0.4863 - f1-score: 0.6279 - val_loss: 0.5326 - val_iou_score: 0.5298 - val_f1-score: 0.6487
# Epoch 10/30
# 91/91 [==============================] - 12s 134ms/step - loss: 0.6358 - iou_score: 0.5163 - f1-score: 0.6581 - val_loss: 0.4771 - val_iou_score: 0.5611 - val_f1-score: 0.6540
# Epoch 11/30
# 91/91 [==============================] - 12s 133ms/step - loss: 0.6368 - iou_score: 0.5168 - f1-score: 0.6519 - val_loss: 0.4920 - val_iou_score: 0.5635 - val_f1-score: 0.6843
# Epoch 12/30
# 91/91 [==============================] - 12s 133ms/step - loss: 0.5817 - iou_score: 0.5375 - f1-score: 0.6807 - val_loss: 0.4392 - val_iou_score: 0.6023 - val_f1-score: 0.7218
# Epoch 13/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.5614 - iou_score: 0.5592 - f1-score: 0.6995 - val_loss: 0.4393 - val_iou_score: 0.6151 - val_f1-score: 0.7355
# Epoch 14/30
# 91/91 [==============================] - 12s 131ms/step - loss: 0.5802 - iou_score: 0.5588 - f1-score: 0.6954 - val_loss: 0.4352 - val_iou_score: 0.5949 - val_f1-score: 0.7040
# Epoch 15/30
# 91/91 [==============================] - 12s 133ms/step - loss: 0.5377 - iou_score: 0.5676 - f1-score: 0.7026 - val_loss: 0.4168 - val_iou_score: 0.6273 - val_f1-score: 0.7417
# Epoch 16/30
# 91/91 [==============================] - 13s 138ms/step - loss: 0.5896 - iou_score: 0.5661 - f1-score: 0.7022 - val_loss: 0.4898 - val_iou_score: 0.5800 - val_f1-score: 0.7034
# Epoch 17/30
# 91/91 [==============================] - 12s 132ms/step - loss: 0.5131 - iou_score: 0.5811 - f1-score: 0.7136 - val_loss: 0.4806 - val_iou_score: 0.5727 - val_f1-score: 0.6950
# Epoch 18/30
# 91/91 [==============================] - 12s 134ms/step - loss: 0.5066 - iou_score: 0.5921 - f1-score: 0.7267 - val_loss: 0.4288 - val_iou_score: 0.6070 - val_f1-score: 0.7080
# Epoch 19/30
# 91/91 [==============================] - 12s 136ms/step - loss: 0.5033 - iou_score: 0.5952 - f1-score: 0.7306 - val_loss: 0.5158 - val_iou_score: 0.5202 - val_f1-score: 0.6357
# Epoch 20/30
# 91/91 [==============================] - 12s 137ms/step - loss: 0.5086 - iou_score: 0.6093 - f1-score: 0.7409 - val_loss: 0.3843 - val_iou_score: 0.6273 - val_f1-score: 0.7395
# Epoch 21/30
# 91/91 [==============================] - 12s 134ms/step - loss: 0.4548 - iou_score: 0.6186 - f1-score: 0.7491 - val_loss: 0.4842 - val_iou_score: 0.5671 - val_f1-score: 0.6909
# Epoch 22/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.4294 - iou_score: 0.6407 - f1-score: 0.7702 - val_loss: 0.4032 - val_iou_score: 0.6096 - val_f1-score: 0.7245
# Epoch 23/30
# 91/91 [==============================] - 12s 136ms/step - loss: 0.4513 - iou_score: 0.6295 - f1-score: 0.7583 - val_loss: 0.4355 - val_iou_score: 0.5920 - val_f1-score: 0.6919
# Epoch 24/30
# 91/91 [==============================] - 12s 136ms/step - loss: 0.4226 - iou_score: 0.6394 - f1-score: 0.7676 - val_loss: 0.4431 - val_iou_score: 0.5801 - val_f1-score: 0.6893
# Epoch 25/30
# 91/91 [==============================] - 12s 134ms/step - loss: 0.4501 - iou_score: 0.6371 - f1-score: 0.7671 - val_loss: 0.4121 - val_iou_score: 0.6145 - val_f1-score: 0.7203
# Epoch 26/30
# 91/91 [==============================] - 12s 135ms/step - loss: 0.4040 - iou_score: 0.6484 - f1-score: 0.7733 - val_loss: 0.3838 - val_iou_score: 0.6520 - val_f1-score: 0.7699
# Epoch 27/30
# 91/91 [==============================] - 12s 133ms/step - loss: 0.4473 - iou_score: 0.6291 - f1-score: 0.7577 - val_loss: 0.3768 - val_iou_score: 0.6468 - val_f1-score: 0.7558
# Epoch 28/30
# 91/91 [==============================] - 12s 134ms/step - loss: 0.3810 - iou_score: 0.6622 - f1-score: 0.7872 - val_loss: 0.3538 - val_iou_score: 0.6661 - val_f1-score: 0.7752
# Epoch 29/30
# 91/91 [==============================] - 12s 132ms/step - loss: 0.3883 - iou_score: 0.6493 - f1-score: 0.7747 - val_loss: 0.4165 - val_iou_score: 0.6111 - val_f1-score: 0.7182
# Epoch 30/30
# 91/91 [==============================] - 12s 132ms/step - loss: 0.3972 - iou_score: 0.6562 - f1-score: 0.7817 - val_loss: 0.3730 - val_iou_score: 0.6384 - val_f1-score: 0.7479

# %%
history = model.fit_generator(
    train_dataloader, 
    steps_per_epoch=len(train_dataloader), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_dataloader, 
    validation_steps=len(valid_dataloader),
)

# %%
# Plot training & validation iou_score values
plt.figure(figsize=(30, 5))
plt.subplot(121)
plt.plot(history.history['iou_score'])
plt.plot(history.history['val_iou_score'])
plt.title('Model iou_score')
plt.ylabel('iou_score')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
test_dataset = Dataset(
    x_test_dir, 
    y_test_dir, 
    classes=CLASSES, 
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
)

test_dataloader = Dataloder(test_dataset, batch_size=1, shuffle=False)

# %%
# load best weights
model.load_weights('best_model.h5')

# %%
scores = model.evaluate_generator(test_dataloader)

print("Loss: {:.5}".format(scores[0]))
for metric, value in zip(metrics, scores[1:]):
    print("mean {}: {:.5}".format(metric.__name__, value))

# %%
n = 20
ids = np.random.choice(np.arange(len(test_dataset)), size=n)

for i in ids:
    
    image, gt_mask = test_dataset[i]
    image = np.expand_dims(image, axis=0)
    pr_mask = model.predict(image).round()
    
    visualize(
        image=denormalize(image.squeeze()),
        gt_mask=gt_mask[..., 0].squeeze(),
        pr_mask=pr_mask[..., 0].squeeze(),
    )
